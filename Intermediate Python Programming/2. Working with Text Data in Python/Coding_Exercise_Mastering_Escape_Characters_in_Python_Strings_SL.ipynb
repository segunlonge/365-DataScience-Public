# %% [markdown]
# ## Mastering Escape Characters in Python Strings

# %% [markdown]
# ![image.png](attachment:bf6af4f7-5e65-4058-8d39-2334a80efc91.png)

# %%
motorcycle_shop = ['New Motorcycles', 'Modern Motorcycles']
motorcycle_brand = ['Ducati', 'Aprilia', 'BMW', 'Suzuki', 'Honda', 'Yamaha', 'Kawasaki']
model_price_usd = [29000, 20000, 33000]

print("Next month, the 'New Motorcycles' shop is expected to sell \nthe newest %s model at a price of \t$33000 per unit." % motorcycle_brand[4])
# Out:
# Next month, the 'New Motorcycles' shop is expected to sell
# the newest Honda model at a price of 	$33000 per unit.
