# %% [markdown]
# ![image.png](attachment:9eff4062-90fb-40a4-8429-f045c2b3c124.png)

# %%
car_brands = ['Ford', 'Chevrolet', 'Cadillac', 'BMW', 'Peugeot', 'Fiat', 'Toyota']
unit_cost_prediction = ['increase', 'decrease', 'remain the same'] 
quarter = [1, 2, 3, 4]

base_string = "{} expects the unit cost of a car to {} in Q{} next year."

# Ford expects the unit cost of a car to increase in Q3 next year.
print(base_string.format(car_brands[0], unit_cost_prediction[0], quarter[2]))

# Toyota expects the unit cost of a car to decrease in Q2 next year.
print(base_string.format(car_brands[6], unit_cost_prediction[1], quarter[1]))

# Cadillac expects the unit cost of a car to remain the same in Q1 next year.
print(base_string.format(car_brands[2], unit_cost_prediction[2], quarter[0]))
# Out:
# Ford expects the unit cost of a car to increase in Q3 next year.
# Toyota expects the unit cost of a car to decrease in Q2 next year.
# Cadillac expects the unit cost of a car to remain the same in Q1 next year.
