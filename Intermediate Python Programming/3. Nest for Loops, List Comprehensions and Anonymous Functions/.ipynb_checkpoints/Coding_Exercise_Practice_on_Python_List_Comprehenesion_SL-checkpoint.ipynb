# %% [markdown]
# ![image.png](attachment:33b37b9c-b8ff-4b12-894f-d814bd30494f.png)

# %%
print([base**exponent for base in range(5,20) if base % 2 == 0 for exponent in range(1,4)])
# Out:
# [6, 36, 216, 8, 64, 512, 10, 100, 1000, 12, 144, 1728, 14, 196, 2744, 16, 256, 4096, 18, 324, 5832]
