# %% [markdown]
# ![image.png](attachment:4901bad9-a22f-42db-92dd-98d111878430.png)

# %%
for i in range(6,20,2):
    for j in range(1,4):
        print(i**j)
# Out:
# 6
# 36
# 216
# 8
# 64
# 512
# 10
# 100
# 1000
# 12
# 144
# 1728
# 14
# 196
# 2744
# 16
# 256
# 4096
# 18
# 324
# 5832
