# %% [markdown]
# ![image.png](attachment:3b00c61f-05e8-431c-bf5d-6102ceeafc38.png)

# %%
import numpy as np

# Create a 1D array
array_1d = np.array([2,6])

# Print the array
print(array_1d)

# Print the shape of the array
print(array_1d.shape)
# Out:
# [2 6]
# (2,)
