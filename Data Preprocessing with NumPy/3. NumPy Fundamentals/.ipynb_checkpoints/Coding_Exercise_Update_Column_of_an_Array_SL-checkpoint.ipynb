# %% [markdown]
# ![image.png](attachment:9dfadab1-be86-4652-a0dc-736b0d35a7d0.png)

# %%
import numpy as np

array_a = np.array([[3, 5, 1], [-2, 0, 6]])
array_b = np.array([[-2, 8], [7, 3], [3, 4]])

array_b[:,1] = array_a[1, :3]

print(array_b)
# Out:
# [[-2 -2]
#  [ 7  0]
#  [ 3  6]]
