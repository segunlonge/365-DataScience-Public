# %% [markdown]
# ![image.png](attachment:16858e83-7a5b-4f94-9613-c969e3d4766c.png)

# %%
import numpy as np

# Array containing the [x, y, z] coordinates of 6 objects
coordinates = np.array([[3, 0.4, -1], [1.8, -2.3, -0.9], [6, 4, 8], [-1, 2.6, 4.2], [0, 0, 12], [-5.3, -2, -6.9]])

# Print the coordinates for object #2, object #4 and object #6
print("Task 1:\n", coordinates[1::2, :])

# Print the [z, x] coordinates of object #1 and object #3
print("\nTask 2:\n", coordinates[:3:2, ::-2])
# Out:
# Task 1:
#  [[ 1.8 -2.3 -0.9]
#  [-1.   2.6  4.2]
#  [-5.3 -2.  -6.9]]
#
# Task 2:
#  [[ 3. -1.]
#  [ 6.  8.]]
