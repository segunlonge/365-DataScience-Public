# %% [markdown]
# ![image.png](attachment:2a8f9d83-96e2-4c13-8831-67e6f9211aad.png)

# %% [markdown]
# My solution (apparently not correct according to the AI)

# %%
import numpy as np

# Array containing the [x, y, z] coordinates of 6 objects
coordinates = np.array([[3, 0.4, -1], [1.8, -2.3, -0.9], [6, 4, 8], [-1, 2.6, 4.2], [0, 0, 12], [-5.3, -2, -6.9]])

# Print the coordinates for object #2, object #3 and object #4
print("Task 1:\n", coordinates[1:4])

# Print the [x, y] coordinates of object #2 
print("\nTask 2:\n", coordinates[1:2,0:2])

# Print the [y, z] coordinates for the last two objects (object #5 and object #6)
print("\nTask 3:\n", coordinates[4:,1:])
# Out:
# Task 1:
#  [[ 1.8 -2.3 -0.9]
#  [ 6.   4.   8. ]
#  [-1.   2.6  4.2]]
#
# Task 2:
#  [[ 1.8 -2.3]]
#
# Task 3:
#  [[ 0.  12. ]
#  [-2.  -6.9]]

# %% [markdown]
# Their solution

# %%
import numpy as np

# Array containing the [x, y, z] coordinates of 6 objects
coordinates = np.array([[3, 0.4, -1], [1.8, -2.3, -0.9], [6, 4, 8], [-1, 2.6, 4.2], [0, 0, 12], [-5.3, -2, -6.9]])

# Print the coordinates for object #2, object #3 and object #4
print("Task 1:\n", coordinates[1:4])

# Print the [x, y] coordinates of object #2 
print("\nTask 2:\n", coordinates[1,:2])

# Print the [y, z] coordinates for the last two objects (object #5 and object #6)
print("\nTask 3:\n", coordinates[4:6,1:])
# Out:
# Task 1:
#  [[ 1.8 -2.3 -0.9]
#  [ 6.   4.   8. ]
#  [-1.   2.6  4.2]]
#
# Task 2:
#  [ 1.8 -2.3]
#
# Task 3:
#  [[ 0.  12. ]
#  [-2.  -6.9]]
