# %% [markdown]
# ![image.png](attachment:2a47d863-b363-469b-9e28-c2ff837810fd.png)

# %%
from numpy.random import Generator as gen
from numpy.random import PCG64 as pcg

array_RG = gen(pcg(seed = 42))
result = array_RG.integers(low = -10, high = 10, size =(3,3))
print(result)
# Out:
# [[-9  5  3]
#  [-2 -2  7]
#  [-9  3 -6]]
