# %% [markdown]
# # Introduction to NumPy

# %% [markdown]
# ## Installing & Updating the Package

# %% [markdown]
# NumPy comes pre-isntalled if you're using Anaconda.
# **pip install numpy**
#
# To get the latest version:
# **pip install numpy --upgrade**

# %% [markdown]
# ### Importing NumPy

# %%
import numpy as np #np is the preferred alias for importing numpy library

# %% [markdown]
# ### Using NumPy

# %%
array_a = np.array([1,2,3]) # This is a 1 dimensional array similar to a vector

# %%
array_a
# Out:
# array([1, 2, 3])

# %%
array_b = np.array([[1,2,3],[4,5,6]]) # This is a 2 dimensional array similar to a matrix i.e. 2 vectors arranged in rows
array_b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ### NumPy Documentation

# %% [markdown]
# https://numpy.org/devdocs/ <- <i> A link to the NumPy documentation
