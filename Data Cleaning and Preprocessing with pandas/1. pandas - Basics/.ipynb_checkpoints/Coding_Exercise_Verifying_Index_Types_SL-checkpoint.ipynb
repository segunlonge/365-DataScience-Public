# %% [markdown]
# ![image.png](attachment:532c4045-d228-4e87-8b45-db72e0db1167.png)

# %%
import pandas as pd
import numpy as np

integers_array = np.array([456, 12, 325, 100])
print(integers_array)

# 1. Convert integers_array into a pandas Series object named 
integers_series = pd.Series(integers_array)

# 2. Use Python indexing to quickly verify that the index values of integers_series 
# are composed of integers. Display the output using the print() function.
print(type(integers_series.index[0]))
# Out:
# [456  12 325 100]
# <class 'int'>
