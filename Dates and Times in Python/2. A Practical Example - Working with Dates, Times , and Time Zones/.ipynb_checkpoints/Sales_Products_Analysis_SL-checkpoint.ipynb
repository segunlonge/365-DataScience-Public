# %% [markdown]
# # Analysis of Product Sales

# %% [markdown]
# Obtain information about the product sales of the various retailer types in UTC offset. Display the average amount of sales that occurred in each time zone

# %%
import pandas as pd
import pytz # Python library used for working with time zones
from datetime import datetime
from matplotlib import pyplot as plt

data = pd.read_csv('Sales-products-tz-mod.csv', index_col='SaleID') #Set SalesID as index of dataframe
sales_data = data.copy()
sales_data.head(20) #Display first 20 records of dataframe
# Out:
#           RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1    United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2    United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3    United States  Outdoors Shop                  Star Dome
# SaleID_4    United States  Outdoors Shop               Star Gazer 2
# SaleID_5            Italy  Outdoors Shop       Canyon Mule Carryall
# SaleID_6            Italy  Outdoors Shop                  Firefly 4
# SaleID_7   United Kingdom  Outdoors Shop              Husky Rope 50
# SaleID_8   United Kingdom  Outdoors Shop      Granite Signal Mirror
# SaleID_9   United Kingdom  Outdoors Shop          Granite Carabiner
# SaleID_10           Italy  Outdoors Shop               Granite Grip
# SaleID_11           Italy  Outdoors Shop                Granite Axe
# SaleID_12          Mexico           Mall              Ranger Vision
# SaleID_13          Mexico           Mall                Trail Scout
# ...

# %%
sales_data[['DateOfSale', 'TimeOfSale', 'TimeZone']].head()
# Out:
#           DateOfSale TimeOfSale TimeZone
# SaleID
# SaleID_1  06/01/2020   23:20:56      EST
# SaleID_2  05/02/2020   17:27:08      EST
# SaleID_3  30/10/2020   09:04:43      EST
# SaleID_4  13/11/2020   04:25:06      EST
# SaleID_5  06/12/2020   11:15:47      CET

# %%
#Concatenate the DateOfSale and TimeOfSale columns
date_and_time = sales_data['DateOfSale'] +" "+ sales_data['TimeOfSale']
date_and_time
# Out:
# SaleID
# SaleID_1      06/01/2020 23:20:56
# SaleID_2      05/02/2020 17:27:08
# SaleID_3      30/10/2020 09:04:43
# SaleID_4      13/11/2020 04:25:06
# SaleID_5      06/12/2020 11:15:47
#                      ...
# SaleID_96     23/07/2019 12:30:03
# SaleID_97     03/01/2019 01:39:14
# SaleID_98     14/02/2019 21:29:35
# SaleID_99     19/06/2020 11:16:19
# SaleID_100    25/05/2019 15:51:41
# Length: 100, dtype: str

# %%
#Convert the concatenated date and time values into a datetime object in a new column in the sales_data dataframe
sales_data['MOS'] = pd.to_datetime(date_and_time, format = '%d/%m/%Y %H:%M:%S') #to_datetime converts strings into DateTime objects
sales_data.head()
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)  DateOfSale TimeOfSale TimeZone  \
# SaleID
# SaleID_1              200.0  06/01/2020   23:20:56      EST
# SaleID_2                7.0  05/02/2020   17:27:08      EST
# SaleID_3               20.0  30/10/2020   09:04:43      EST
# SaleID_4               40.0  13/11/2020   04:25:06      EST
# SaleID_5              150.5  06/12/2020   11:15:47      CET
#
#                          MOS
# SaleID
# SaleID_1 2020-01-06 23:20:56
# SaleID_2 2020-02-05 17:27:08
# SaleID_3 2020-10-30 09:04:43
# SaleID_4 2020-11-13 04:25:06
# ...

# %%
#Drop the DateofSale and TimeOfSale columns since they are now merged into the new column MOS and new table called sales_data_2
sales_data_2 = sales_data.drop(['DateOfSale','TimeOfSale'], axis = 1) #axis = 0 operate on rows; axis = 1 operate on columns
sales_data_2.head()
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($) TimeZone                 MOS
# SaleID
# SaleID_1              200.0      EST 2020-01-06 23:20:56
# SaleID_2                7.0      EST 2020-02-05 17:27:08
# SaleID_3               20.0      EST 2020-10-30 09:04:43
# SaleID_4               40.0      EST 2020-11-13 04:25:06
# SaleID_5              150.5      CET 2020-12-06 11:15:47

# %%
# View the Olson timezone database, use a empty list to get in nice format first time round
alltimezones = []
alltimezones = pytz.all_timezones
alltimezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
#Want to check whether the timezones in the sales_data dataframe are in the Olson database
#sales_data['TimeZone'].unique()
for i in sales_data_2['TimeZone'].unique():
    if i in pytz.all_timezones:
        print(True)
    else:
        print(False, i)
# Out:
# True
# True
# True
# True
# False SGT
# True

# %%
# Since Singapore (not SGT) is in the Olson list then replace SGT with Singapore
sales_data_2.loc[:, 'TimeZone'] = sales_data_2.loc[:, 'TimeZone'].replace({'SGT': 'Singapore'})

# Check
sales_data_2['TimeZone'].unique()
# Out:
# <ArrowStringArray>
# ['EST', 'CET', 'GMT', 'EET', 'Singapore', 'Australia/West']
# Length: 6, dtype: str

# %%
# Select rows where TimeZone is 'Singapore'
sales_data_2[sales_data_2['TimeZone'] == 'Singapore']
# Out:
#           RetailerCountry     RetailerType                Product  \
# SaleID
# SaleID_18       Singapore    Outdoors Shop         Granite Pulley
# SaleID_19       Singapore    Outdoors Shop  Firefly Climbing Lamp
# SaleID_20       Singapore    Outdoors Shop            Granite Ice
# SaleID_21       Singapore    Outdoors Shop    Mountain Man Analog
# SaleID_22       Singapore    Outdoors Shop   Mountain Man Digital
# SaleID_23       Singapore    Outdoors Shop    Mountain Man Deluxe
# SaleID_81       Singapore  Warehouse Store      EverGlow Kerosene
# SaleID_82       Singapore    Outdoors Shop                     TX
#
#            Sales Revenue ($)   TimeZone                 MOS
# SaleID
# SaleID_18              19.00  Singapore 2019-01-02 01:32:09
# SaleID_19              23.45  Singapore 2019-02-20 07:07:10
# SaleID_20              65.00  Singapore 2019-04-10 10:27:26
# SaleID_21              10.00  Singapore 2019-07-10 05:20:29
# ...

# %%
# Turn off Python's row and column truncation
pd.options.display.max_rows = None
pd.options.display.max_columns = None
sales_data_2
# Out:
#            RetailerCountry       RetailerType                         Product  \
# SaleID
# SaleID_1     United States      Outdoors Shop       TrailChef Deluxe Cook Set
# SaleID_2     United States      Outdoors Shop          TrailChef Double Flame
# SaleID_3     United States      Outdoors Shop                       Star Dome
# SaleID_4     United States      Outdoors Shop                    Star Gazer 2
# SaleID_5             Italy      Outdoors Shop            Canyon Mule Carryall
# SaleID_6             Italy      Outdoors Shop                       Firefly 4
# SaleID_7    United Kingdom      Outdoors Shop                   Husky Rope 50
# SaleID_8    United Kingdom      Outdoors Shop           Granite Signal Mirror
# SaleID_9    United Kingdom      Outdoors Shop               Granite Carabiner
# SaleID_10            Italy      Outdoors Shop                    Granite Grip
# SaleID_11            Italy      Outdoors Shop                     Granite Axe
# ...

# %%
# using iloc to give the value of the first row of the MOS column
sales_data_2['MOS'].iloc[0]
# Out:
# Timestamp('2020-01-06 23:20:56')

# %%
# Make the date in the first row of the MOS column timezone aware
sales_data_2['MOS'].iloc[0].tz_localize(sales_data_2['TimeZone'].iloc[0])
# Out:
# Timestamp('2020-01-06 23:20:56-0500', tz='EST')

# %%
# Create timezone aware dates for all the dates in the MOS column

list_mos_timestamps = [] #Initiatise list to store timezone aware dates

# raise an exception in case of amibigiuos or nonexistent dates
# ambiguous and nonexistent handle problems caused by Daylight Saving Time (DST) when you localize a timestamp to a timezone
# An ambiguous time occurs when clocks go backward at the end of DST, causing the same local time to occur twice
# A nonexistent time occurs when clocks go forward at the start of DST, causing some local times to be skipped
for i in range(len(sales_data_2)):
    list_mos_timestamps.append(pd.to_datetime(sales_data_2['MOS'].iloc[i].tz_localize(sales_data_2['TimeZone'].iloc[i], ambiguous='raise', nonexistent='raise')))

# Use list slicing to display the first 10 rows of the data set
list_mos_timestamps[:10]

# Display all data set
list_mos_timestamps
# Out:
# [Timestamp('2020-01-06 23:20:56-0500', tz='EST'),
#  Timestamp('2020-02-05 17:27:08-0500', tz='EST'),
#  Timestamp('2020-10-30 09:04:43-0500', tz='EST'),
#  Timestamp('2020-11-13 04:25:06-0500', tz='EST'),
#  Timestamp('2020-12-06 11:15:47+0100', tz='CET'),
#  Timestamp('2020-06-07 01:54:41+0200', tz='CET'),
#  Timestamp('2020-12-27 02:07:28+0000', tz='GMT'),
#  Timestamp('2020-09-15 11:44:57+0000', tz='GMT'),
#  Timestamp('2020-09-23 01:40:29+0000', tz='GMT'),
#  Timestamp('2020-06-24 18:43:04+0200', tz='CET'),
#  Timestamp('2019-05-19 02:12:30+0200', tz='CET'),
#  Timestamp('2019-04-05 07:38:10-0500', tz='EST'),
#  Timestamp('2020-01-24 08:51:28-0500', tz='EST'),
#  Timestamp('2019-12-07 08:14:53-0500', tz='EST'),
#  Timestamp('2020-01-13 05:32:40-0500', tz='EST'),
#  Timestamp('2020-11-26 10:17:48+0200', tz='EET'),
#  Timestamp('2020-01-23 19:36:25+0200', tz='EET'),
#  Timestamp('2019-01-02 01:32:09+0800', tz='Singapore'),
#  Timestamp('2019-02-20 07:07:10+0800', tz='Singapore'),
# ...

# %%
# Obtaining different values from the time aware list of dattime rows

# Get date time in string format to the specified format
print(list_mos_timestamps[0].strftime('%Y-%m-%d %H:%M:%S'))

# Get information about the UTC offset object
print(list_mos_timestamps[0].strftime('%z'))

# Convert the offset into a numeric value
print(float(list_mos_timestamps[0].strftime('%z'))/100)

# Get the date part of the datetime object
print(list_mos_timestamps[0].date())

# Get the time part of the datetime object
print(list_mos_timestamps[0].time())

# Get the relevant offset of the datetime object
print(list_mos_timestamps[0].utcoffset())

# Get the relevant offset (in seconds) of the datetime object
print(list_mos_timestamps[0].utcoffset().total_seconds()/3600)
# Out:
# 2020-01-06 23:20:56
# -0500
# -5.0
# 2020-01-06
# 23:20:56
# -1 day, 19:00:00
# -5.0

# %%
# Use a list comprehension to get the UTC offset for all the date values and put in new column in data frame
sales_data_2['OffsetUTC'] = [list_mos_timestamps[i].utcoffset().total_seconds() / 3600 for i in range(len(sales_data_2))]

sales_data_2.head()
# Out:
#          RetailerCountry   RetailerType                    Product  \
# SaleID
# SaleID_1   United States  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2   United States  Outdoors Shop     TrailChef Double Flame
# SaleID_3   United States  Outdoors Shop                  Star Dome
# SaleID_4   United States  Outdoors Shop               Star Gazer 2
# SaleID_5           Italy  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($) TimeZone                 MOS  OffsetUTC
# SaleID
# SaleID_1              200.0      EST 2020-01-06 23:20:56       -5.0
# SaleID_2                7.0      EST 2020-02-05 17:27:08       -5.0
# SaleID_3               20.0      EST 2020-10-30 09:04:43       -5.0
# SaleID_4               40.0      EST 2020-11-13 04:25:06       -5.0
# SaleID_5              150.5      CET 2020-12-06 11:15:47        1.0

# %%
# Reorder the columns in the data frame
column_names_reordered = ['RetailerCountry', 'MOS', 'TimeZone', 'OffsetUTC', 'RetailerType', 'Product', 'Sales Revenue ($)']
sales_data_2 = sales_data_2[column_names_reordered]
sales_data_2.head()
# Out:
#          RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_1   United States 2020-01-06 23:20:56      EST       -5.0
# SaleID_2   United States 2020-02-05 17:27:08      EST       -5.0
# SaleID_3   United States 2020-10-30 09:04:43      EST       -5.0
# SaleID_4   United States 2020-11-13 04:25:06      EST       -5.0
# SaleID_5           Italy 2020-12-06 11:15:47      CET        1.0
#
#            RetailerType                    Product  Sales Revenue ($)
# SaleID
# SaleID_1  Outdoors Shop  TrailChef Deluxe Cook Set              200.0
# SaleID_2  Outdoors Shop     TrailChef Double Flame                7.0
# SaleID_3  Outdoors Shop                  Star Dome               20.0
# SaleID_4  Outdoors Shop               Star Gazer 2               40.0
# SaleID_5  Outdoors Shop       Canyon Mule Carryall              150.5

# %%
# Do a count by TimeZone and OffsetUTC
sales_data_2.groupby(['TimeZone', 'OffsetUTC']).count()
# Out:
#                           RetailerCountry  MOS  RetailerType  Product  \
# TimeZone       OffsetUTC
# Australia/West  8.0                    17   17            17       17
# CET             1.0                     5    5             5        5
#                 2.0                    11   11            11       11
# EET             2.0                     4    4             4        4
#                 3.0                     4    4             4        4
# EST            -5.0                    40   40            40       40
# GMT             0.0                    11   11            11       11
# Singapore       8.0                     8    8             8        8
#
#                           Sales Revenue ($)
# TimeZone       OffsetUTC
# Australia/West  8.0                      17
# CET             1.0                       5
#                 2.0                      11
# EET             2.0                       4
#                 3.0                       4
# ...

# %%
# Filter for the CET TimeZone
sales_data_2[sales_data_2['TimeZone']=='CET'].sort_values('OffsetUTC')
# Out:
#           RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_5            Italy 2020-12-06 11:15:47      CET        1.0
# SaleID_31         Germany 2019-02-24 19:16:17      CET        1.0
# SaleID_73     Switzerland 2019-03-26 09:52:36      CET        1.0
# SaleID_75     Switzerland 2019-03-14 22:25:10      CET        1.0
# SaleID_83         Austria 2020-03-10 21:42:37      CET        1.0
# SaleID_10           Italy 2020-06-24 18:43:04      CET        2.0
# SaleID_11           Italy 2019-05-19 02:12:30      CET        2.0
# SaleID_6            Italy 2020-06-07 01:54:41      CET        2.0
# SaleID_72     Switzerland 2019-05-30 06:36:09      CET        2.0
# SaleID_30         Germany 2019-05-21 14:03:10      CET        2.0
# SaleID_76     Switzerland 2020-06-04 12:36:06      CET        2.0
# SaleID_74     Switzerland 2020-07-03 14:17:34      CET        2.0
# SaleID_77         Austria 2020-05-11 13:06:45      CET        2.0
# ...

# %%
# Sorting the MOS column would not be appropriate as they are not UTC formatted so would give a misleading order of chronology so it is necessary to 
# convert to UTC
sales_data_2['MOS-UTC'] = [pd.to_datetime(sales_data['MOS'].iloc[i]).tz_localize(sales_data_2['TimeZone'].iloc[i]).tz_convert('UTC')
                           for i in range(len(sales_data_2))]

# %%
# The new sales table table with UTC formatted MOS column called MOS-UTC
sales_data_2.head()
# Out:
#          RetailerCountry                 MOS TimeZone  OffsetUTC  \
# SaleID
# SaleID_1   United States 2020-01-06 23:20:56      EST       -5.0
# SaleID_2   United States 2020-02-05 17:27:08      EST       -5.0
# SaleID_3   United States 2020-10-30 09:04:43      EST       -5.0
# SaleID_4   United States 2020-11-13 04:25:06      EST       -5.0
# SaleID_5           Italy 2020-12-06 11:15:47      CET        1.0
#
#            RetailerType                    Product  Sales Revenue ($)  \
# SaleID
# SaleID_1  Outdoors Shop  TrailChef Deluxe Cook Set              200.0
# SaleID_2  Outdoors Shop     TrailChef Double Flame                7.0
# SaleID_3  Outdoors Shop                  Star Dome               20.0
# SaleID_4  Outdoors Shop               Star Gazer 2               40.0
# SaleID_5  Outdoors Shop       Canyon Mule Carryall              150.5
#
#                            MOS-UTC
# SaleID
# SaleID_1 2020-01-07 04:20:56+00:00
# SaleID_2 2020-02-05 22:27:08+00:00
# ...

# %%
# Re-order the column to put MOS-UTC first
column_names_reordered = ['RetailerCountry', 'MOS-UTC', 'MOS', 'TimeZone', 'OffsetUTC', 'RetailerType', 'Product', 'Sales Revenue ($)']
sales_data_2 = sales_data_2[column_names_reordered]

# %%
# The new sales data table showing the chronological order of sales according to UTC and not local time
sales_data_2.head()
# Out:
#          RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_1   United States 2020-01-07 04:20:56+00:00 2020-01-06 23:20:56
# SaleID_2   United States 2020-02-05 22:27:08+00:00 2020-02-05 17:27:08
# SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# SaleID_5           Italy 2020-12-06 10:15:47+00:00 2020-12-06 11:15:47
#
#          TimeZone  OffsetUTC   RetailerType                    Product  \
# SaleID
# SaleID_1      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# SaleID_3      EST       -5.0  Outdoors Shop                  Star Dome
# SaleID_4      EST       -5.0  Outdoors Shop               Star Gazer 2
# SaleID_5      CET        1.0  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)
# SaleID
# SaleID_1              200.0
# ...

# %%
# Sales data sorted in chronological order using MOS-UTC column
# Note the difference between the MOS_UTC and MOS datetime values for the first row
sales_data_2.sort_values(['MOS-UTC'])
# Out:
#            RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_18        Singapore 2019-01-01 17:32:09+00:00 2019-01-02 01:32:09
# SaleID_97        Australia 2019-01-02 17:39:14+00:00 2019-01-03 01:39:14
# SaleID_53           Canada 2019-01-03 20:40:25+00:00 2019-01-03 15:40:25
# SaleID_55           Canada 2019-01-11 00:37:17+00:00 2019-01-10 19:37:17
# SaleID_37           Canada 2019-01-11 19:24:52+00:00 2019-01-11 14:24:52
# SaleID_33           Canada 2019-01-16 18:33:16+00:00 2019-01-16 13:33:16
# SaleID_87        Australia 2019-01-18 20:29:44+00:00 2019-01-19 04:29:44
# SaleID_60           Canada 2019-02-02 04:10:36+00:00 2019-02-01 23:10:36
# SaleID_98        Australia 2019-02-14 13:29:35+00:00 2019-02-14 21:29:35
# SaleID_19        Singapore 2019-02-19 23:07:10+00:00 2019-02-20 07:07:10
# SaleID_31          Germany 2019-02-24 18:16:17+00:00 2019-02-24 19:16:17
# SaleID_94        Australia 2019-03-03 14:51:15+00:00 2019-03-03 22:51:15
# ...

# %%
# What is the average offset?
sales_data_2.groupby('TimeZone').mean(numeric_only=True)
# Out:
#                 OffsetUTC  Sales Revenue ($)
# TimeZone
# Australia/West     8.0000         273.105882
# CET                1.6875         415.710000
# EET                2.5000         586.687500
# EST               -5.0000         230.385500
# GMT                0.0000         115.137273
# Singapore          8.0000          27.688750

# %%
# An overview of how many sales have occured in each time zone
# Also indicates no missing data given by the same number across rows
sales_data_2.groupby('TimeZone').count()
# Out:
#                 RetailerCountry  MOS-UTC  MOS  OffsetUTC  RetailerType  \
# TimeZone
# Australia/West               17       17   17         17            17
# CET                          16       16   16         16            16
# EET                           8        8    8          8             8
# EST                          40       40   40         40            40
# GMT                          11       11   11         11            11
# Singapore                     8        8    8          8             8
#
#                 Product  Sales Revenue ($)
# TimeZone
# Australia/West       17                 17
# CET                  16                 16
# EET                   8                  8
# EST                  40                 40
# GMT                  11                 11
# Singapore             8                  8

# %%
# Group by using more thant 2 columns
sales_data_2.groupby(['TimeZone', 'OffsetUTC']).count()
# Out:
#                           RetailerCountry  MOS-UTC  MOS  RetailerType  \
# TimeZone       OffsetUTC
# Australia/West  8.0                    17       17   17            17
# CET             1.0                     5        5    5             5
#                 2.0                    11       11   11            11
# EET             2.0                     4        4    4             4
#                 3.0                     4        4    4             4
# EST            -5.0                    40       40   40            40
# GMT             0.0                    11       11   11            11
# Singapore       8.0                     8        8    8             8
#
#                           Product  Sales Revenue ($)
# TimeZone       OffsetUTC
# Australia/West  8.0            17                 17
# CET             1.0             5                  5
#                 2.0            11                 11
# EET             2.0             4                  4
# ...

# %%
# Sort the data frame from highest number of sales to lowest number of sales
sales_data_2.groupby(['TimeZone', 'OffsetUTC']).count().sort_values('Product', ascending = False)
# Out:
#                           RetailerCountry  MOS-UTC  MOS  RetailerType  \
# TimeZone       OffsetUTC
# EST            -5.0                    40       40   40            40
# Australia/West  8.0                    17       17   17            17
# GMT             0.0                    11       11   11            11
# CET             2.0                    11       11   11            11
# Singapore       8.0                     8        8    8             8
# CET             1.0                     5        5    5             5
# EET             2.0                     4        4    4             4
#                 3.0                     4        4    4             4
#
#                           Product  Sales Revenue ($)
# TimeZone       OffsetUTC
# EST            -5.0            40                 40
# Australia/West  8.0            17                 17
# GMT             0.0            11                 11
# CET             2.0            11                 11
# ...

# %%
sales_data_2.head()
# Out:
#          RetailerCountry                   MOS-UTC                 MOS  \
# SaleID
# SaleID_1   United States 2020-01-07 04:20:56+00:00 2020-01-06 23:20:56
# SaleID_2   United States 2020-02-05 22:27:08+00:00 2020-02-05 17:27:08
# SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# SaleID_5           Italy 2020-12-06 10:15:47+00:00 2020-12-06 11:15:47
#
#          TimeZone  OffsetUTC   RetailerType                    Product  \
# SaleID
# SaleID_1      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# SaleID_2      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# SaleID_3      EST       -5.0  Outdoors Shop                  Star Dome
# SaleID_4      EST       -5.0  Outdoors Shop               Star Gazer 2
# SaleID_5      CET        1.0  Outdoors Shop       Canyon Mule Carryall
#
#           Sales Revenue ($)
# SaleID
# SaleID_1              200.0
# ...

# %%
# reset_index() is pandas method that moves the current index back into a regular column and creates a new default integer index.
sales_data_2_viz = sales_data_2.reset_index()
sales_data_2_viz.head()
# Out:
#      SaleID RetailerCountry                   MOS-UTC                 MOS  \
# 0  SaleID_1   United States 2020-01-07 04:20:56+00:00 2020-01-06 23:20:56
# 1  SaleID_2   United States 2020-02-05 22:27:08+00:00 2020-02-05 17:27:08
# 2  SaleID_3   United States 2020-10-30 14:04:43+00:00 2020-10-30 09:04:43
# 3  SaleID_4   United States 2020-11-13 09:25:06+00:00 2020-11-13 04:25:06
# 4  SaleID_5           Italy 2020-12-06 10:15:47+00:00 2020-12-06 11:15:47
#
#   TimeZone  OffsetUTC   RetailerType                    Product  \
# 0      EST       -5.0  Outdoors Shop  TrailChef Deluxe Cook Set
# 1      EST       -5.0  Outdoors Shop     TrailChef Double Flame
# 2      EST       -5.0  Outdoors Shop                  Star Dome
# 3      EST       -5.0  Outdoors Shop               Star Gazer 2
# 4      CET        1.0  Outdoors Shop       Canyon Mule Carryall
#
#    Sales Revenue ($)
# 0              200.0
# 1                7.0
# 2               20.0
# 3               40.0
# 4              150.5

# %%
# set the new dataframe index to MOS-UTC and sort ascendingly
sales_data_2_viz = sales_data_2_viz.set_index('MOS-UTC').sort_index()
sales_data_2_viz.head()
# Out:
#                               SaleID RetailerCountry                 MOS  \
# MOS-UTC
# 2019-01-01 17:32:09+00:00  SaleID_18       Singapore 2019-01-02 01:32:09
# 2019-01-02 17:39:14+00:00  SaleID_97       Australia 2019-01-03 01:39:14
# 2019-01-03 20:40:25+00:00  SaleID_53          Canada 2019-01-03 15:40:25
# 2019-01-11 00:37:17+00:00  SaleID_55          Canada 2019-01-10 19:37:17
# 2019-01-11 19:24:52+00:00  SaleID_37          Canada 2019-01-11 14:24:52
#
#                                  TimeZone  OffsetUTC      RetailerType  \
# MOS-UTC
# 2019-01-01 17:32:09+00:00       Singapore        8.0     Outdoors Shop
# 2019-01-02 17:39:14+00:00  Australia/West        8.0  Department Store
# 2019-01-03 20:40:25+00:00             EST       -5.0      Sports Store
# 2019-01-11 00:37:17+00:00             EST       -5.0      Sports Store
# 2019-01-11 19:24:52+00:00             EST       -5.0     Outdoors Shop
#
#                                      Product  Sales Revenue ($)
# MOS-UTC
# ...

# %%
# Plot of 'OffsetUTC' against the index column
sales_data_2_viz['OffsetUTC'].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='MOS-UTC'>

# %%
# Do a scatter plot of OffsetUTC against RetailerType
plt.scatter(sales_data_2_viz['OffsetUTC'], sales_data_2_viz['RetailerType'])

# %%
# Group By and sum the Sales Revenue
sales_data_2_viz.groupby('TimeZone')['Sales Revenue ($)'].sum()
# Out:
# TimeZone
# Australia/West    4642.80
# CET               6651.36
# EET               4693.50
# EST               9215.42
# GMT               1266.51
# Singapore          221.51
# Name: Sales Revenue ($), dtype: float64

# %%
total_sales_revenue_by_timezone = sales_data_2_viz.groupby('TimeZone')['Sales Revenue ($)'].sum()

total_sales_revenue_by_timezone_df = pd.DataFrame(total_sales_revenue_by_timezone)
total_sales_revenue_by_timezone_df
# Out:
#                 Sales Revenue ($)
# TimeZone
# Australia/West            4642.80
# CET                       6651.36
# EET                       4693.50
# EST                       9215.42
# GMT                       1266.51
# Singapore                  221.51

# %%
# Plot a bar char of the dataframe: total_sales_revenue_by_timezone_df
plt.bar(total_sales_revenue_by_timezone_df.index,
        height = total_sales_revenue_by_timezone_df['Sales Revenue ($)'])
# Out:
# <BarContainer object of 6 artists>

# %%
"""
Plot a bar char of the dataframe: total_sales_revenue_by_timezone_df
settings:
    figure: adjust the size of the plot graph
    color: colour of the barchar
    rotation: angle of the xticks (labels)
    fontsize: size of xtics fonts
"""
plt.figure(figsize = (7,6))

plt.bar(total_sales_revenue_by_timezone_df.index,
        height = total_sales_revenue_by_timezone_df['Sales Revenue ($)'],
       color = '#108A99')

plt.xticks(rotation = 35, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales Revenue by Time Zone", fontsize = 18, fontweight = "bold")
plt.ylabel("Sales Revenue ($)")

plt.show()

# %%
# Group By and average the Sales Revenue
# sales_data_2_viz.groupby(['TimeZone'])['Sales Revenue ($)'].mean()

averages_by_time_zone = sales_data_2_viz.groupby('TimeZone')['Sales Revenue ($)'].mean().sort_values(ascending = False)
averages_by_time_zone_df = pd.DataFrame(averages_by_time_zone)

averages_by_time_zone_df
# Out:
#                 Sales Revenue ($)
# TimeZone
# EET                    586.687500
# CET                    415.710000
# Australia/West         273.105882
# EST                    230.385500
# GMT                    115.137273
# Singapore               27.688750

# %%
plt.figure(figsize = (7,6))

plt.bar(averages_by_time_zone_df.index,
        height = averages_by_time_zone_df['Sales Revenue ($)'],
       color = ["green", "blue", "red", "darkblue", "yellow", "purple"])

plt.xticks(rotation = 35, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Average Sales Revenue by Time Zone", fontsize = 18, fontweight = "bold")
plt.ylabel("Average Sales Revenue ($)")

plt.show()
