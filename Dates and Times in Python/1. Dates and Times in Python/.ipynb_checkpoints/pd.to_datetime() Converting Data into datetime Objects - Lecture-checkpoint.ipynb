# %%
from datetime import datetime

# %%
string_datetime = '10:25:30 2021-02-20'
string_datetime
# Out:
# '10:25:30 2021-02-20'

# %%
type(string_datetime)
# Out:
# str

# %%
my_first_datetime = datetime.strptime(string_datetime, '%H:%M:%S %Y-%m-%d')
my_first_datetime
# Out:
# datetime.datetime(2021, 2, 20, 10, 25, 30)

# %% [markdown]
# ###  pd.to_datetime(): Converting Data into datetime Objects

# %%
import pandas as pd

# %%
my_new_datetime = pd.to_datetime(string_datetime, format = '%H:%M:%S %Y-%m-%d')
my_new_datetime
# Out:
# Timestamp('2021-02-20 10:25:30')

# %%
type(my_new_datetime)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# without the "format" parameter:
my_new_datetime = pd.to_datetime(string_datetime)
my_new_datetime
# Out:
# Timestamp('2021-02-20 10:25:30')

# %%
my_new_datetime.hour
# Out:
# 10

# %%
my_new_datetime.minute
# Out:
# 25

# %%
my_new_datetime.second
# Out:
# 30

# %%
my_new_datetime.year
# Out:
# 2021

# %%
my_new_datetime.month
# Out:
# 2

# %%
my_new_datetime.day
# Out:
# 20

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'LoanID')
lending_co_data = data.copy()
lending_co_data.head()
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B           Male   Location 3  Region 2     17600.0
# 2       LoanID_2  Product B         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product C           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product B           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product D         Female  Location 34  Region 3     21250.0
#
#          StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1       04/07/2018     2200         45          365       3221       4166
# 2       02/01/2019     2200         45          365       3161       4096
# 3       08/12/2016     1000         45          365       2260       3205
# 4              NaN     2200         45          365       3141       4166
# 5       28/10/2017     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# LoanID
# 1            14621     Active
# 2            16041     Active
# 3            16340        NaN
# 4            16321     Active
# 5            14720     Active

# %%
# we are interested in 'StartDate'
lending_co_data['StartDate'].head()
# Out:
# LoanID
# 1    04/07/2018
# 2    02/01/2019
# 3    08/12/2016
# 4           NaN
# 5    28/10/2017
# Name: StartDate, dtype: object

# %%
pd.to_datetime(lending_co_data['StartDate'])
# Out:
# LoanID
# 1      2018-04-07
# 2      2019-02-01
# 3      2016-08-12
# 4             NaT
# 5      2017-10-28
#           ...
# 1039   2018-12-29
# 1040   2018-03-28
# 1041   2018-04-26
# 1042   2016-10-25
# 1043   2019-05-15
# Name: StartDate, Length: 1043, dtype: datetime64[ns]

# %%
lending_co_data['StartDate'] = pd.to_datetime(lending_co_data['StartDate'])
lending_co_data.head()
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B           Male   Location 3  Region 2     17600.0
# 2       LoanID_2  Product B         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product C           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product B           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product D         Female  Location 34  Region 3     21250.0
#
#         StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1      2018-04-07     2200         45          365       3221       4166
# 2      2019-02-01     2200         45          365       3161       4096
# 3      2016-08-12     1000         45          365       2260       3205
# 4             NaT     2200         45          365       3141       4166
# 5      2017-10-28     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# LoanID
# 1            14621     Active
# 2            16041     Active
# 3            16340        NaN
# 4            16321     Active
# 5            14720     Active
