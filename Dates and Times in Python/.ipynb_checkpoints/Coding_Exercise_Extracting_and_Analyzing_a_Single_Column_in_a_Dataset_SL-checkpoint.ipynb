# %% [markdown]
# ![image.png](attachment:9175e7dc-c5c7-4058-b6cf-56c9d26bfa62.png)

# %%
import pandas as pd

# Step 1: Load the dataset
data = pd.read_csv('Lending-company.csv', index_col='LoanID')
lending_data = data.copy()
lending_data.head()

# Step 2: Check the original data type of 'StartDate'
print("Original 'StartDate' dtype:", lending_data['StartDate'].dtype)
# Out:
# Original 'StartDate' dtype: str
