# %% [markdown]
#  # Coding Exercise: Searching for patterns in Text

# %% [markdown]
# In this exercise, you will use regular expressions to check for specific patterns in a block of text. You are given a string **s** with some lines of text.
#
# Your task is to create two patterns and check if they exist in the text.
# 1. Check if the letter q appears anywhere in the text. Print True or False accordingly.
# 2. Check if there is an i followed by any whitespace character (space, tab, or newline) and then a u. Print True or False accordingly.
#
# *Hint: You can transform the result of re.search() to a boolean directly - e.g. bool(pattern.search(s)).*

# %%
import re

s = "Dou shitatte kesenai yume mo tomarenai ima mo\nDareka no tame ni tsuyoku nareru nara\nArigatou kanashimi yo\nSekai ni uchinomesarete makeru imi wo shitta\nGuren no hana yo sakihokore\nUnmei wo terashite"

# Find if there is a 'q' in the string
pattern = re.compile(r'q')
print(bool(pattern.search(s)))

# Find if there is 'i', followed by whitespace and then a 'u' in the string
pattern = re.compile(r"i\s+u")
print(bool(pattern.search(s)))
# Out:
# False
# True
